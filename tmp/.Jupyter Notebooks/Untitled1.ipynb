# %%
import pandas as pd

mageck_df = pd.read_csv("fullTest/Mageck/fullTest_Bottom_Sorted_mageck_gene_results.csv")

# %%
sorted_df = mageck_df.sort_values(by="pos|-log(p-value)", ascending=False)

# %%
sorted_df.head()
# Out:
#    Unnamed: 0       id  num  neg|score  neg|p-value  neg|fdr  neg|rank  \
# 0           0    Strap    4    1.00000       1.0000      1.0     19672
# 5           1     Bbs4    4    0.99982       0.9999      1.0     19614
# 8           3     Cct2    4    1.00000       1.0000      1.0     19670
# 7           2  Tmem231    4    1.00000       1.0000      1.0     19671
# 6           4      Smo    4    1.00000       1.0000      1.0     19669
#
#    neg|goodsgrna  neg|lfc     pos|score   pos|p-value  pos|fdr  pos|rank  \
# 0              0      0.0  1.057900e-09  2.395500e-07  0.00055         1
# 5              0      0.0  1.619100e-08  2.395500e-07  0.00055         2
# 8              0      0.0  3.155600e-08  2.395500e-07  0.00055         4
# 7              0      0.0  2.823500e-08  2.395500e-07  0.00055         3
# 6              0      0.0  5.841500e-08  2.395500e-07  0.00055         5
#
#    pos|goodsgrna  pos|lfc  neg|-log(p-value)  pos|-log(p-value)
# ...
